# %%
import pandas as pd

# %%
df = pd.read_csv('formated_csv/final.csv')

# %%
add = pd.read_csv('formated_csv/remaining_bracket_data.csv')

# %%
add2 = pd.read_csv('formated_csv/county_in_brackers2.csv')

# %%
add3 = pd.read_csv('formated_csv/NANwithCounty2.csv')

# %%
add4 = pd.read_csv('formated_csv/MonCounty2.csv')

# %%
result = pd.concat([df,add,add2,add3,add4])

# %%
result
# Out:
#            date      state_name state_id   county_name    city_or_county  \
# 0      1/1/2014        Michigan       MI      Muskegon          Muskegon
# 1      1/1/2014      New Jersey       NJ         Essex            Newark
# 2      1/1/2014        New York       NY        Queens            Queens
# 3      1/1/2014        New York       NY         Kings          Brooklyn
# 4      1/1/2014        Missouri       MO        Greene       Springfield
# 5      1/1/2014         Georgia       GA      Muscogee          Columbus
# 6      1/1/2014        New York       NY      Onondaga          Syracuse
# 7      1/1/2014        Kentucky       KY       Fayette         Lexington
# 8      1/1/2014    Pennsylvania       PA  Philadelphia      Philadelphia
# 9      1/1/2014        Virginia       VA      Hampton            Hampton
# 10     1/1/2014  South Carolina       SC    Charleston  North Charleston
# 11     1/1/2014        Maryland       MD    Baltimore          Baltimore
# ...

# %%
result.to_csv('formated_csv/final2.csv')
